# %%
import course;course.header()
# Out:
# # Advanced Python Course
# ## Mobi Heidelberg WS 2021/22
# ### by Christian Fufezan
#
# christian@fufezan.net
#
# https://fufezan.net
#
# <img src="./images/cc.png" alt="drawing" width="200" style="float: left;"/>

# %% [markdown]
# # Pandas level 1
# Data wrangling 101

# %% [markdown]
# I'd like to say Pandas is numpy on steroids but it is actually much more.
#
# Pandas is the data science solution for Python and it build on top of the powerful numpy module.
# However, Pandas offers elements that are much more intuitive or go beyond what numpy has ever provided.
# Nevertheless, numpy is more performant in some cases (by a lot, yet remember when to optimize!)
#
# The perfect is the dead of the good.
#  -- M. Gunner
#
# Pandas was create [Wes McKinney](https://wesmckinney.com/pages/about.html) in the early 2008 at AQR capital management and I can recommend "Python for Data Analysis" from Wes, which was published via O'Reilly and "Pandas for Everyone" by Daniel Y. Chen. The following Pandas chapters are inspired by the books.

# %% [markdown]
# Pandas offers the two basic data structures
# * Series
# * Dataframes

# %%
import pandas as pd

# %%
c = pd.Series(
    [12, 13, 14, 121], 
    index=['r1', 'r2', 'r3', 'r4']
)
c
# Out:
# r1     12
# r2     13
# r3     14
# r4    121
# dtype: int64

# %% [markdown]
# Selecting from Series works like a dict :)

# %%
c['r2']
# Out:
# 13

# %%
mask = c >= 13
mask
# Out:
# r1    False
# r2     True
# r3     True
# r4     True
# dtype: bool

# %%
c[mask]
# Out:
# r2     13
# r3     14
# r4    121
# dtype: int64

# %% [markdown]
# Masks can be additive!

# %%
mask2 = c < 20
c[mask & mask2]
# Out:
# r2    13
# r3    14
# dtype: int64

# %%
c * 10
# Out:
# r1     120
# r2     130
# r3     140
# r4    1210
# dtype: int64

# %%
# works also with vectorized math operations 
import numpy as np
np.exp(c)
# Out:
# r1    1.627548e+05
# r2    4.424134e+05
# r3    1.202604e+06
# r4    3.545131e+52
# dtype: float64

# %% [markdown]
# Remember to use numpy functions as much as possible so data remains on the "C side". More below!

# %% [markdown]
# Operations conserve index!
#
# Series are like ordered Dicts!

# %%
'r1' in c
# Out:
# True

# %% [markdown]
# np.nan is the missing value indicator

# %%
d = pd.Series(
    {
        'r1': np.nan, 
        'r2': 0.2, 
        'r3': 0.2, 
        'r4': 0.4
    }
)

# %%
d
# Out:
# r1    NaN
# r2    0.2
# r3    0.2
# r4    0.4
# dtype: float64

# %% [markdown]
# ### Which values are nan?

# %%
d.isna() # returns a mask!
# Out:
# r1     True
# r2    False
# r3    False
# r4    False
# dtype: bool

# %%
# inverting with ~!
~d.isna()
# Out:
# r1    False
# r2     True
# r3     True
# r4     True
# dtype: bool

# %%
d.notnull()
# Out:
# r1    False
# r2     True
# r3     True
# r4     True
# dtype: bool

# %% [markdown]
# ## indices are aligned automatically!

# %%
c
# Out:
# r1     12
# r2     13
# r3     14
# r4    121
# dtype: int64

# %%
d = pd.Series(
    [10,20,30,40], 
    index=['r2', 'r3', 'r4', 'r5']
)
d
# Out:
# r2    10
# r3    20
# r4    30
# r5    40
# dtype: int64

# %%
c + d
# Out:
# r1      NaN
# r2     23.0
# r3     34.0
# r4    151.0
# r5      NaN
# dtype: float64

# %% [markdown]
# ## Renaming index

# %%
d.index = ['r1', 'r2', 'r3', 'r4'] # now the indices are the same in c and d!

# %%
c + d
# Out:
# r1     22
# r2     33
# r3     44
# r4    161
# dtype: int64

# %% [markdown]
# Naming things will help you to get your data organised better. Explicit is better than implicit! And remember to choose your names variable wisely - you will code read often than you write.

# %%
d.index.name = "variable"
d.name = "counts"
d
# Out:
# variable
# r1    10
# r2    20
# r3    30
# r4    40
# Name: counts, dtype: int64

# %%
d.reset_index()
# Out:
#   variable  counts
# 0       r1      10
# 1       r2      20
# 2       r3      30
# 3       r4      40

# %% [markdown]
# Resetting index turns the index into a series so now we hav a DataFrame with two series!

# %%
type(d.reset_index())
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Data frames
# Data frames are the pandas 2d data containers (if there is only one index dimension).
# In principle data frames are a list of Series, whereas each row is a series.

# %%
df = pd.DataFrame(
    [
        c, 
        d, # this one we named :)
        pd.Series([100,102,103,104], index=['r2', 'r3', 'r4', 'r5'])
    ]
)
df
# Out:
#              r1     r2     r3     r4     r5
# Unnamed 0  12.0   13.0   14.0  121.0    NaN
# counts     10.0   20.0   30.0   40.0    NaN
# Unnamed 1   NaN  100.0  102.0  103.0  104.0

# %%
# accessing a value
df.loc['counts', 'r2']
# Out:
# 20.0

# %% [markdown]
# Note: How pandas aligns your data automatically.
#
# If you want each series to be treated as column, just transpose

# %% [markdown]
# DataFrames can be constructed in many different ways, see docu for more details
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html?highlight=dataframe#pandas.DataFrame

# %%
df = df.T
df
# Out:
#     Unnamed 0  counts  Unnamed 1
# r1       12.0    10.0        NaN
# r2       13.0    20.0      100.0
# r3       14.0    30.0      102.0
# r4      121.0    40.0      103.0
# r5        NaN     NaN      104.0

# %% [markdown]
# Renaming columns in a data frame

# %%
df.columns = ['count1', 'count2', 'count3']
df
# Out:
#     count1  count2  count3
# r1    12.0    10.0     NaN
# r2    13.0    20.0   100.0
# r3    14.0    30.0   102.0
# r4   121.0    40.0   103.0
# r5     NaN     NaN   104.0

# %% [markdown]
# Dataframes can equally be named, for your sanity, name them :)

# %%
df.columns.name = "Counts"
df.index.name = "variable"
df
# Out:
# Counts    count1  count2  count3
# variable
# r1          12.0    10.0     NaN
# r2          13.0    20.0   100.0
# r3          14.0    30.0   102.0
# r4         121.0    40.0   103.0
# r5           NaN     NaN   104.0

# %% [markdown]
# Now that you feel happy in the pandas world, some modules/functions require numpy arrays, how do you convert them ?

# %%
np_df = df.values
np_df
# Out:
# array([[ 12.,  10.,  nan],
#        [ 13.,  20., 100.],
#        [ 14.,  30., 102.],
#        [121.,  40., 103.],
#        [ nan,  nan, 104.]])

# %%
type(np_df)
# Out:
# numpy.ndarray

# %% [markdown]
# If you need to work "longer" on the numpy side, I suggest to transform the pandas dataframe to a numpy recarray, as names are preserved;

# %%
# np_df = df.values # 
np_df = df.to_records()
np_df
# Out:
# rec.array([('r1',  12., 10.,  nan), ('r2',  13., 20., 100.),
#            ('r3',  14., 30., 102.), ('r4', 121., 40., 103.),
#            ('r5',  nan, nan, 104.)],
#           dtype=[('variable', 'O'), ('count1', '<f8'), ('count2', '<f8'), ('count3', '<f8')])

# %%
np_df['variable']
# Out:
# array(['r1', 'r2', 'r3', 'r4', 'r5'], dtype=object)

# %%
np_df[0]
# Out:
# ('r1', 12., 10., nan)

# %%
np_df[0][2]
# Out:
# 10.0

# %% [markdown]
# ## C-side and Python side

# %% [markdown]
# **Note**:
# Regular Python floats live in the Python world - Numpy and Pandas live in the "C world", hence their fast vectorized operations. If you can avoid it, don't cast between the worlds!

# %%
long_series = pd.Series(
    np.random.randn(1000000), 
)

# %%
# %%timeit -n 1
a = long_series.to_list()  # to python list!
print(f"a is a {type(a)} now!")
pd.Series(a)
# Out:
# a is a <class 'list'> now!
# a is a <class 'list'> now!
# a is a <class 'list'> now!
# a is a <class 'list'> now!
# a is a <class 'list'> now!
# a is a <class 'list'> now!
# a is a <class 'list'> now!
# 137 ms ± 11 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit -n 1
a = long_series.to_numpy()
print(f"a is a {type(a)} now!")
pd.Series(a)
# Out:
# a is a <class 'numpy.ndarray'> now!
# a is a <class 'numpy.ndarray'> now!
# a is a <class 'numpy.ndarray'> now!
# a is a <class 'numpy.ndarray'> now!
# a is a <class 'numpy.ndarray'> now!
# a is a <class 'numpy.ndarray'> now!
# a is a <class 'numpy.ndarray'> now!
# The slowest run took 5.04 times longer than the fastest. This could mean that an intermediate result is being cached.
# 227 µs ± 172 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# # Operations between DataFrame and Series

# %%
df_small = pd.DataFrame([c, d])
df_small
# Out:
#            r1  r2  r3   r4
# Unnamed 0  12  13  14  121
# counts     10  20  30   40

# %%
c
# Out:
# r1     12
# r2     13
# r3     14
# r4    121
# dtype: int64

# %%
df_small - c
# Out:
#            r1  r2  r3  r4
# Unnamed 0   0   0   0   0
# counts     -2   7  16 -81

# %% [markdown]
# Next time you want to normalize each row of a data frame, one can define the correction factors as a series and just e.g. subtract it.

# %%
df
# Out:
# Counts    count1  count2  count3
# variable
# r1          12.0    10.0     NaN
# r2          13.0    20.0   100.0
# r3          14.0    30.0   102.0
# r4         121.0    40.0   103.0
# r5           NaN     NaN   104.0

# %%
df.rename(
    columns={'count1':'count_reference'}, 
    inplace=True
)

# %%
df
# Out:
# Counts    count_reference  count2  count3
# variable
# r1                   12.0    10.0     NaN
# r2                   13.0    20.0   100.0
# r3                   14.0    30.0   102.0
# r4                  121.0    40.0   103.0
# r5                    NaN     NaN   104.0

# %%
# subselecting a set of columns! 
df[["count2", 'count3']]
# Out:
# Counts    count2  count3
# variable
# r1          10.0     NaN
# r2          20.0   100.0
# r3          30.0   102.0
# r4          40.0   103.0
# r5           NaN   104.0

# %% [markdown]
# **Note:**
# This only creates a view of the data!

# %% [markdown]
# # Pandas IO
# Pandas comes with a wide array of input output modules see
# https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html
#
# **NOTE:** reading xlsx is _much_ slower than csv

# %% [markdown]
# Your request: Scraping websites!
#
# Today with Pandas scraping wikipedia. In particular the oldest universities!
#
# Alternatively beautiful soup https://www.crummy.com/software/BeautifulSoup/bs4/doc/ or Scrapy https://scrapy.org/

# %%
url = "https://en.wikipedia.org/wiki/List_of_oldest_universities_in_continuous_operation"

# %% [markdown]
# Lets bail out of the SSL context for the sake of this class :)

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
dfs = pd.read_html(url) # do you get SSL: CERTIFICATE_VERIFY_FAILED ?

# %%
len(dfs)
# Out:
# 8

# %%
dfs[0].head()
# Out:
#                                    Year               University  \
#                                    Year               University
# 0  1180–1190[10](teaching from c. 1088)    University of Bologna
# 1  1200–1214[15](teaching from c. 1096)     University of Oxford
# 2                         1209–1225[24]  University of Cambridge
# 3                         1218–1219[24]  University of Salamanca
# 4                              1222[24]      University of Padua
#
#                               Location                             \
#                               Original                    Current
# 0  Kingdom of Italy, Holy Roman Empire             Bologna, Italy
# 1                   Kingdom of England     Oxford, United Kingdom
# 2                   Kingdom of England  Cambridge, United Kingdom
# 3                      Kingdom of León           Salamanca, Spain
# 4            Medieval commune of Padua               Padua, Italy
#
#                                                Notes
#                                                Notes
# 0  Law schools existed in Bologna from the second...
# 1  Teaching existed in Oxford from the late 11th ...
# 2  Founded by scholars leaving Oxford after a dis...
# 3  The oldest university in the Hispanic world. T...
# 4  Founded by scholars and professors after leavi...

# %%
udf = dfs[0]

# %%
udf.columns
# Out:
# MultiIndex([(      'Year',       'Year'),
#             ('University', 'University'),
#             (  'Location',   'Original'),
#             (  'Location',    'Current'),
#             (     'Notes',      'Notes')],
#            )

# %% [markdown]
# Multi index makes pandas very powerful but it takes time to get used to them, see more below.
#
# For now let's get rid of them...

# %%
udf.columns = [ e[0] for e in udf.columns ]

# %%
udf.head()
# Out:
#                                    Year               University  \
# 0  1180–1190[10](teaching from c. 1088)    University of Bologna
# 1  1200–1214[15](teaching from c. 1096)     University of Oxford
# 2                         1209–1225[24]  University of Cambridge
# 3                         1218–1219[24]  University of Salamanca
# 4                              1222[24]      University of Padua
#
#                               Location                   Location  \
# 0  Kingdom of Italy, Holy Roman Empire             Bologna, Italy
# 1                   Kingdom of England     Oxford, United Kingdom
# 2                   Kingdom of England  Cambridge, United Kingdom
# 3                      Kingdom of León           Salamanca, Spain
# 4            Medieval commune of Padua               Padua, Italy
#
#                                                Notes
# 0  Law schools existed in Bologna from the second...
# 1  Teaching existed in Oxford from the late 11th ...
# 2  Founded by scholars leaving Oxford after a dis...
# 3  The oldest university in the Hispanic world. T...
# 4  Founded by scholars and professors after leavi...

# %%
udf.columns = ['Year', 'University', 'H-Location', 'G-Location', 'Notes' ]

# %%
udf.head()
# Out:
#                                    Year               University  \
# 0  1180–1190[10](teaching from c. 1088)    University of Bologna
# 1  1200–1214[15](teaching from c. 1096)     University of Oxford
# 2                         1209–1225[24]  University of Cambridge
# 3                         1218–1219[24]  University of Salamanca
# 4                              1222[24]      University of Padua
#
#                             H-Location                 G-Location  \
# 0  Kingdom of Italy, Holy Roman Empire             Bologna, Italy
# 1                   Kingdom of England     Oxford, United Kingdom
# 2                   Kingdom of England  Cambridge, United Kingdom
# 3                      Kingdom of León           Salamanca, Spain
# 4            Medieval commune of Padua               Padua, Italy
#
#                                                Notes
# 0  Law schools existed in Bologna from the second...
# 1  Teaching existed in Oxford from the late 11th ...
# 2  Founded by scholars leaving Oxford after a dis...
# 3  The oldest university in the Hispanic world. T...
# 4  Founded by scholars and professors after leavi...

# %% [markdown]
# Most of the time, this data needs cleanup, e.g. year should most optimally be a date or at least a year.

# %% [markdown]
# ## Gather some basic information around the dataframe

# %%
udf.describe()
# Out:
#                                         Year             University  \
# count                                     35                     35
# unique                                    35                     35
# top     1180–1190[10](teaching from c. 1088)  University of Bologna
# freq                                       1                      1
#
#                H-Location      G-Location  \
# count                  35              35
# unique                 20              35
# top     Holy Roman Empire  Bologna, Italy
# freq                    9               1
#
#                                                     Notes
# count                                                  24
# unique                                                 24
# top     Law schools existed in Bologna from the second...
# freq                                                    1

# %%
udf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        35 non-null     object
#  1   University  35 non-null     object
#  2   H-Location  35 non-null     object
#  3   G-Location  35 non-null     object
#  4   Notes       24 non-null     object
# dtypes: object(5)
# memory usage: 1.5+ KB

# %% [markdown]
# Cleaning up data takes a lot time and needs to be done diligently!
#
# Let's clean-up the Year column
#
# Accessing the str properties!

# %%
udf['Year'].str.match(r'^(?P<year>[0-9]{4})')
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15    False
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# Name: Year, dtype: bool

# %%
udf.loc[15]
# Out:
# Year                c. 1400[24](originally 1343 to c. 1360)[24]
# University                                   University of Pisa
# H-Location                                     Republic of Pisa
# G-Location                                          Pisa, Italy
# Notes         Established 1343 but closed around 1360; refou...
# Name: 15, dtype: object

# %%
udf['year'] = udf.Year.str.extract(r'(?P<year>[0-9]{4})')

# %%
udf.head()
# Out:
#                                    Year               University  \
# 0  1180–1190[10](teaching from c. 1088)    University of Bologna
# 1  1200–1214[15](teaching from c. 1096)     University of Oxford
# 2                         1209–1225[24]  University of Cambridge
# 3                         1218–1219[24]  University of Salamanca
# 4                              1222[24]      University of Padua
#
#                             H-Location                 G-Location  \
# 0  Kingdom of Italy, Holy Roman Empire             Bologna, Italy
# 1                   Kingdom of England     Oxford, United Kingdom
# 2                   Kingdom of England  Cambridge, United Kingdom
# 3                      Kingdom of León           Salamanca, Spain
# 4            Medieval commune of Padua               Padua, Italy
#
#                                                Notes  year
# 0  Law schools existed in Bologna from the second...  1180
# 1  Teaching existed in Oxford from the late 11th ...  1200
# 2  Founded by scholars leaving Oxford after a dis...  1209
# 3  The oldest university in the Hispanic world. T...  1218
# 4  Founded by scholars and professors after leavi...  1222

# %%
udf.loc[15]
# Out:
# Year                c. 1400[24](originally 1343 to c. 1360)[24]
# University                                   University of Pisa
# H-Location                                     Republic of Pisa
# G-Location                                          Pisa, Italy
# Notes         Established 1343 but closed around 1360; refou...
# year                                                       1400
# Name: 15, dtype: object

# %%
udf.shape
# (rows, columns)
# Out:
# (35, 6)

# %% [markdown]
# One cannot visualize all columns straight away in jupyter :( However redefining some options helps!

# %%
pd.set_option("max_columns", 2000)

# %% [markdown]
# # Sorting

# %%
udf.head()
# Out:
#                                    Year               University  \
# 0  1180–1190[10](teaching from c. 1088)    University of Bologna
# 1  1200–1214[15](teaching from c. 1096)     University of Oxford
# 2                         1209–1225[24]  University of Cambridge
# 3                         1218–1219[24]  University of Salamanca
# 4                              1222[24]      University of Padua
#
#                             H-Location                 G-Location  \
# 0  Kingdom of Italy, Holy Roman Empire             Bologna, Italy
# 1                   Kingdom of England     Oxford, United Kingdom
# 2                   Kingdom of England  Cambridge, United Kingdom
# 3                      Kingdom of León           Salamanca, Spain
# 4            Medieval commune of Padua               Padua, Italy
#
#                                                Notes  year
# 0  Law schools existed in Bologna from the second...  1180
# 1  Teaching existed in Oxford from the late 11th ...  1200
# 2  Founded by scholars leaving Oxford after a dis...  1209
# 3  The oldest university in the Hispanic world. T...  1218
# 4  Founded by scholars and professors after leavi...  1222

# %%
udf.sort_values(['year'])
# Out:
#                                            Year  \
# 0          1180–1190[10](teaching from c. 1088)
# 1          1200–1214[15](teaching from c. 1096)
# 2                                 1209–1225[24]
# 3                                 1218–1219[24]
# 4                                      1222[24]
# 5                                      1224[24]
# 6                                      1290[24]
# 7             1293 (Papal recognition 1346)[24]
# 8                                      1308[24]
# 9                                      1347[24]
# 10           1357[24](originally 1246–1252)[24]
# 11                                     1361[24]
# 12                                     1365[24]
# 13                                     1385[24]
# 14    1397[24](originally 1364-before 1370)[24]
# 15  c. 1400[24](originally 1343 to c. 1360)[24]
# 16                                     1404[24]
# 17                                     1409[24]
# 18                            1410[24]–1413[43]
# 19                                     1419[24]
# 20           1430[24](originally 1391–1394)[24]
# 21     1431[24](originally 1303 to c. 1400)[24]
# 22                                     1444[24]
# 23                                     1450[24]
# 24                                     1451[24]
# 25                                     1456[24]
# 26                                     1457[24]
# 27                                     1459[24]
# 28                            1459[24]–1472[60]
# 29                                     1475[24]
# 30                                     1476[24]
# 31                                     1477[24]
# 32                                     1495[24]
# 33                                     1499[24]
# 34                                     1500[24]
#
#                                 University  \
# 0                    University of Bologna
# 1                     University of Oxford
# 2                  University of Cambridge
# 3                  University of Salamanca
# 4                      University of Padua
# 5         University of Naples Federico II
# 6                    University of Coimbra
# 7                 University of Valladolid
# 8                    University of Perugia
# 9                       Charles University
# 10                     University of Siena
# 11                     University of Pavia
# 12                    University of Vienna
# 13  Ruprecht Karl University of Heidelberg
# 14                 Jagiellonian University
# 15                      University of Pisa
# 16                     University of Turin
# 17                   University of Leipzig
# 18               University of St. Andrews
# 19                   University of Rostock
# 20                   University of Ferrara
# 21             Sapienza University of Rome
# 22                   University of Catania
# 23                 University of Barcelona
# 24                   University of Glasgow
# 25                University of Greifswald
# 26   Albert Ludwigs University of Freiburg
# 27                     University of Basel
# 28  Ludwig Maximilian University of Munich
# 29                University of Copenhagen
# 30   Eberhard Karls University of Tübingen
# 31                      Uppsala University
# 32                  University of Aberdeen
# 33        Complutense University of Madrid
# 34                  University of Valencia
#
#                                     H-Location                   G-Location  \
# 0          Kingdom of Italy, Holy Roman Empire               Bologna, Italy
# 1                           Kingdom of England       Oxford, United Kingdom
# 2                           Kingdom of England    Cambridge, United Kingdom
# 3                              Kingdom of León             Salamanca, Spain
# 4                    Medieval commune of Padua                 Padua, Italy
# 5                            Kingdom of Sicily                Naples, Italy
# 6                          Kingdom of Portugal            Coimbra, Portugal
# 7                             Crown of Castile            Valladolid, Spain
# 8                                 Papal States               Perugia, Italy
# 9        Kingdom of Bohemia, Holy Roman Empire       Prague, Czech Republic
# 10                           Republic of Siena                 Siena, Italy
# 11             Domain of the House of Visconti                 Pavia, Italy
# 12                           Holy Roman Empire              Vienna, Austria
# 13                           Holy Roman Empire          Heidelberg, Germany
# 14                           Kingdom of Poland               Kraków, Poland
# 15                            Republic of Pisa                  Pisa, Italy
# 16                              Duchy of Savoy                 Turin, Italy
# 17                           Holy Roman Empire             Leipzig, Germany
# 18                         Kingdom of Scotland  St. Andrews, United Kingdom
# 19                           Holy Roman Empire             Rostock, Germany
# 20                               House of Este               Ferrara, Italy
# 21                                Papal States                  Rome, Italy
# 22                           Kingdom of Sicily               Catania, Italy
# 23                             Crown of Aragon             Barcelona, Spain
# 24                         Kingdom of Scotland      Glasgow, United Kingdom
# 25                           Holy Roman Empire          Greifswald, Germany
# 26                           Holy Roman Empire            Freiburg, Germany
# 27                           Holy Roman Empire           Basel, Switzerland
# 28                           Holy Roman Empire              Munich, Germany
# 29  Kingdom of Denmark within the Kalmar Union          Copenhagen, Denmark
# 30                           Holy Roman Empire            Tübingen, Germany
# 31   Kingdom of Sweden within the Kalmar Union              Uppsala, Sweden
# 32                         Kingdom of Scotland     Aberdeen, United Kingdom
# 33                            Crown of Castile                Madrid, Spain
# 34                             Crown of Aragon              Valencia, Spain
#
#                                                 Notes  year
# 0   Law schools existed in Bologna from the second...  1180
# 1   Teaching existed in Oxford from the late 11th ...  1200
# 2   Founded by scholars leaving Oxford after a dis...  1209
# 3   The oldest university in the Hispanic world. T...  1218
# 4   Founded by scholars and professors after leavi...  1222
# 5   Claims to be the oldest public university in t...  1224
# 6   Originally established in Lisbon but relocated...  1290
# 7   Founded in the late 13th century,[24] probably...  1293
# 8   The university traces its history back to 1276...  1308
# 9   Faculties of theology, law and medicine closed...  1347
# 10  Claims to have been founded in 1240 by the Com...  1357
# 11  Transferred to Piacenza 1398–1412.[24] Closed ...  1361
# 12                                                NaN  1365
# 13                                                NaN  1385
# 14  Founded by King Casimir the Great as a studium...  1397
# 15  Established 1343 but closed around 1360; refou...  1400
# 16                                                NaN  1404
# 17                                                NaN  1409
# 18  A school of higher studies was founded in 1410...  1410
# 19  Continuous operation during the Reformation is...  1419
# 20                                                NaN  1430
# 21  Founded in 1303 but closed at the end of the 1...  1431
# 22                                                NaN  1444
# 23  Founded by Alfonso V of Aragon on 3 September ...  1450
# 24                                                NaN  1451
# 25  Some professors from Rostock taught temporaril...  1456
# 26  A papal bull of 1455 authorised the Bishop of ...  1457
# 27                                                NaN  1459
# 28  Founded in Ingolstadt in 1472; with a papal bu...  1459
# 29                                                NaN  1475
# 30                                                NaN  1476
# 31  Established in 1477 by the Catholic Archbishop...  1477
# 32  King's College was founded by a papal bull in ...  1495
# 33  A studium generale was founded by Sancho IV of...  1499
# 34                                                NaN  1500

# %% [markdown]
# Sort_values has kwargs like ascending = True|False and values are defined by a list, ie sort first by, then by ...

# %%
udf.sort_values(['H-Location','year'])
# Out:
#                                            Year  \
# 23                                     1450[24]
# 34                                     1500[24]
# 7             1293 (Papal recognition 1346)[24]
# 33                                     1499[24]
# 11                                     1361[24]
# 16                                     1404[24]
# 12                                     1365[24]
# 13                                     1385[24]
# 17                                     1409[24]
# 19                                     1419[24]
# 25                                     1456[24]
# 26                                     1457[24]
# 27                                     1459[24]
# 28                            1459[24]–1472[60]
# 30                                     1476[24]
# 20           1430[24](originally 1391–1394)[24]
# 9                                      1347[24]
# 29                                     1475[24]
# 1          1200–1214[15](teaching from c. 1096)
# 2                                 1209–1225[24]
# 0          1180–1190[10](teaching from c. 1088)
# 3                                 1218–1219[24]
# 14    1397[24](originally 1364-before 1370)[24]
# 6                                      1290[24]
# 18                            1410[24]–1413[43]
# 24                                     1451[24]
# 32                                     1495[24]
# 5                                      1224[24]
# 22                                     1444[24]
# 31                                     1477[24]
# 4                                      1222[24]
# 8                                      1308[24]
# 21     1431[24](originally 1303 to c. 1400)[24]
# 15  c. 1400[24](originally 1343 to c. 1360)[24]
# 10           1357[24](originally 1246–1252)[24]
#
#                                 University  \
# 23                 University of Barcelona
# 34                  University of Valencia
# 7                 University of Valladolid
# 33        Complutense University of Madrid
# 11                     University of Pavia
# 16                     University of Turin
# 12                    University of Vienna
# 13  Ruprecht Karl University of Heidelberg
# 17                   University of Leipzig
# 19                   University of Rostock
# 25                University of Greifswald
# 26   Albert Ludwigs University of Freiburg
# 27                     University of Basel
# 28  Ludwig Maximilian University of Munich
# 30   Eberhard Karls University of Tübingen
# 20                   University of Ferrara
# 9                       Charles University
# 29                University of Copenhagen
# 1                     University of Oxford
# 2                  University of Cambridge
# 0                    University of Bologna
# 3                  University of Salamanca
# 14                 Jagiellonian University
# 6                    University of Coimbra
# 18               University of St. Andrews
# 24                   University of Glasgow
# 32                  University of Aberdeen
# 5         University of Naples Federico II
# 22                   University of Catania
# 31                      Uppsala University
# 4                      University of Padua
# 8                    University of Perugia
# 21             Sapienza University of Rome
# 15                      University of Pisa
# 10                     University of Siena
#
#                                     H-Location                   G-Location  \
# 23                             Crown of Aragon             Barcelona, Spain
# 34                             Crown of Aragon              Valencia, Spain
# 7                             Crown of Castile            Valladolid, Spain
# 33                            Crown of Castile                Madrid, Spain
# 11             Domain of the House of Visconti                 Pavia, Italy
# 16                              Duchy of Savoy                 Turin, Italy
# 12                           Holy Roman Empire              Vienna, Austria
# 13                           Holy Roman Empire          Heidelberg, Germany
# 17                           Holy Roman Empire             Leipzig, Germany
# 19                           Holy Roman Empire             Rostock, Germany
# 25                           Holy Roman Empire          Greifswald, Germany
# 26                           Holy Roman Empire            Freiburg, Germany
# 27                           Holy Roman Empire           Basel, Switzerland
# 28                           Holy Roman Empire              Munich, Germany
# 30                           Holy Roman Empire            Tübingen, Germany
# 20                               House of Este               Ferrara, Italy
# 9        Kingdom of Bohemia, Holy Roman Empire       Prague, Czech Republic
# 29  Kingdom of Denmark within the Kalmar Union          Copenhagen, Denmark
# 1                           Kingdom of England       Oxford, United Kingdom
# 2                           Kingdom of England    Cambridge, United Kingdom
# 0          Kingdom of Italy, Holy Roman Empire               Bologna, Italy
# 3                              Kingdom of León             Salamanca, Spain
# 14                           Kingdom of Poland               Kraków, Poland
# 6                          Kingdom of Portugal            Coimbra, Portugal
# 18                         Kingdom of Scotland  St. Andrews, United Kingdom
# 24                         Kingdom of Scotland      Glasgow, United Kingdom
# 32                         Kingdom of Scotland     Aberdeen, United Kingdom
# 5                            Kingdom of Sicily                Naples, Italy
# 22                           Kingdom of Sicily               Catania, Italy
# 31   Kingdom of Sweden within the Kalmar Union              Uppsala, Sweden
# 4                    Medieval commune of Padua                 Padua, Italy
# 8                                 Papal States               Perugia, Italy
# 21                                Papal States                  Rome, Italy
# 15                            Republic of Pisa                  Pisa, Italy
# 10                           Republic of Siena                 Siena, Italy
#
#                                                 Notes  year
# 23  Founded by Alfonso V of Aragon on 3 September ...  1450
# 34                                                NaN  1500
# 7   Founded in the late 13th century,[24] probably...  1293
# 33  A studium generale was founded by Sancho IV of...  1499
# 11  Transferred to Piacenza 1398–1412.[24] Closed ...  1361
# 16                                                NaN  1404
# 12                                                NaN  1365
# 13                                                NaN  1385
# 17                                                NaN  1409
# 19  Continuous operation during the Reformation is...  1419
# 25  Some professors from Rostock taught temporaril...  1456
# 26  A papal bull of 1455 authorised the Bishop of ...  1457
# 27                                                NaN  1459
# 28  Founded in Ingolstadt in 1472; with a papal bu...  1459
# 30                                                NaN  1476
# 20                                                NaN  1430
# 9   Faculties of theology, law and medicine closed...  1347
# 29                                                NaN  1475
# 1   Teaching existed in Oxford from the late 11th ...  1200
# 2   Founded by scholars leaving Oxford after a dis...  1209
# 0   Law schools existed in Bologna from the second...  1180
# 3   The oldest university in the Hispanic world. T...  1218
# 14  Founded by King Casimir the Great as a studium...  1397
# 6   Originally established in Lisbon but relocated...  1290
# 18  A school of higher studies was founded in 1410...  1410
# 24                                                NaN  1451
# 32  King's College was founded by a papal bull in ...  1495
# 5   Claims to be the oldest public university in t...  1224
# 22                                                NaN  1444
# 31  Established in 1477 by the Catholic Archbishop...  1477
# 4   Founded by scholars and professors after leavi...  1222
# 8   The university traces its history back to 1276...  1308
# 21  Founded in 1303 but closed at the end of the 1...  1431
# 15  Established 1343 but closed around 1360; refou...  1400
# 10  Claims to have been founded in 1240 by the Com...  1357

# %% [markdown]
# Let split the G-location into city and country!

# %%
tmp_df = udf['G-Location'].str.split(",")
display(tmp_df.head())   # not quite what we want .. we want two columns!
# Out:
# 0               [Bologna,  Italy]
# 1       [Oxford,  United Kingdom]
# 2    [Cambridge,  United Kingdom]
# 3             [Salamanca,  Spain]
# 4                 [Padua,  Italy]
# Name: G-Location, dtype: object

# %% [markdown]
# How to get two columns?

# %%
tmp_df = udf['G-Location'].str.split(",", expand=True)
tmp_df.columns = ['G-City', 'G-Country']

# %%
tmp_df
# Out:
#          G-City        G-Country
# 0       Bologna            Italy
# 1        Oxford   United Kingdom
# 2     Cambridge   United Kingdom
# 3     Salamanca            Spain
# 4         Padua            Italy
# 5        Naples            Italy
# 6       Coimbra         Portugal
# 7    Valladolid            Spain
# 8       Perugia            Italy
# 9        Prague   Czech Republic
# 10        Siena            Italy
# 11        Pavia            Italy
# 12       Vienna          Austria
# 13   Heidelberg          Germany
# 14       Kraków           Poland
# 15         Pisa            Italy
# 16        Turin            Italy
# 17      Leipzig          Germany
# 18  St. Andrews   United Kingdom
# 19      Rostock          Germany
# 20      Ferrara            Italy
# 21         Rome            Italy
# 22      Catania            Italy
# 23    Barcelona            Spain
# 24      Glasgow   United Kingdom
# 25   Greifswald          Germany
# 26     Freiburg          Germany
# 27        Basel      Switzerland
# 28       Munich          Germany
# 29   Copenhagen          Denmark
# 30     Tübingen          Germany
# 31      Uppsala           Sweden
# 32     Aberdeen   United Kingdom
# 33       Madrid            Spain
# 34     Valencia            Spain

# %%
udf = udf.join(tmp_df)
# there are many options to join frames

# %%
udf.head()
# Out:
#                                    Year               University  \
# 0  1180–1190[10](teaching from c. 1088)    University of Bologna
# 1  1200–1214[15](teaching from c. 1096)     University of Oxford
# 2                         1209–1225[24]  University of Cambridge
# 3                         1218–1219[24]  University of Salamanca
# 4                              1222[24]      University of Padua
#
#                             H-Location                 G-Location  \
# 0  Kingdom of Italy, Holy Roman Empire             Bologna, Italy
# 1                   Kingdom of England     Oxford, United Kingdom
# 2                   Kingdom of England  Cambridge, United Kingdom
# 3                      Kingdom of León           Salamanca, Spain
# 4            Medieval commune of Padua               Padua, Italy
#
#                                                Notes  year     G-City  \
# 0  Law schools existed in Bologna from the second...  1180    Bologna
# 1  Teaching existed in Oxford from the late 11th ...  1200     Oxford
# 2  Founded by scholars leaving Oxford after a dis...  1209  Cambridge
# 3  The oldest university in the Hispanic world. T...  1218  Salamanca
# 4  Founded by scholars and professors after leavi...  1222      Padua
#
#          G-Country
# 0            Italy
# 1   United Kingdom
# 2   United Kingdom
# 3            Spain
# 4            Italy

# %% [markdown]
# # Deleting things

# %%
udf.head()
# Out:
#                                    Year               University  \
# 0  1180–1190[10](teaching from c. 1088)    University of Bologna
# 1  1200–1214[15](teaching from c. 1096)     University of Oxford
# 2                         1209–1225[24]  University of Cambridge
# 3                         1218–1219[24]  University of Salamanca
# 4                              1222[24]      University of Padua
#
#                             H-Location                 G-Location  \
# 0  Kingdom of Italy, Holy Roman Empire             Bologna, Italy
# 1                   Kingdom of England     Oxford, United Kingdom
# 2                   Kingdom of England  Cambridge, United Kingdom
# 3                      Kingdom of León           Salamanca, Spain
# 4            Medieval commune of Padua               Padua, Italy
#
#                                                Notes  year     G-City  \
# 0  Law schools existed in Bologna from the second...  1180    Bologna
# 1  Teaching existed in Oxford from the late 11th ...  1200     Oxford
# 2  Founded by scholars leaving Oxford after a dis...  1209  Cambridge
# 3  The oldest university in the Hispanic world. T...  1218  Salamanca
# 4  Founded by scholars and professors after leavi...  1222      Padua
#
#          G-Country
# 0            Italy
# 1   United Kingdom
# 2   United Kingdom
# 3            Spain
# 4            Italy

# %%
udf.drop(1)
# Out:
#                                            Year  \
# 0          1180–1190[10](teaching from c. 1088)
# 2                                 1209–1225[24]
# 3                                 1218–1219[24]
# 4                                      1222[24]
# 5                                      1224[24]
# 6                                      1290[24]
# 7             1293 (Papal recognition 1346)[24]
# 8                                      1308[24]
# 9                                      1347[24]
# 10           1357[24](originally 1246–1252)[24]
# 11                                     1361[24]
# 12                                     1365[24]
# 13                                     1385[24]
# 14    1397[24](originally 1364-before 1370)[24]
# 15  c. 1400[24](originally 1343 to c. 1360)[24]
# 16                                     1404[24]
# 17                                     1409[24]
# 18                            1410[24]–1413[43]
# 19                                     1419[24]
# 20           1430[24](originally 1391–1394)[24]
# 21     1431[24](originally 1303 to c. 1400)[24]
# 22                                     1444[24]
# 23                                     1450[24]
# 24                                     1451[24]
# 25                                     1456[24]
# 26                                     1457[24]
# 27                                     1459[24]
# 28                            1459[24]–1472[60]
# 29                                     1475[24]
# 30                                     1476[24]
# 31                                     1477[24]
# 32                                     1495[24]
# 33                                     1499[24]
# 34                                     1500[24]
#
#                                 University  \
# 0                    University of Bologna
# 2                  University of Cambridge
# 3                  University of Salamanca
# 4                      University of Padua
# 5         University of Naples Federico II
# 6                    University of Coimbra
# 7                 University of Valladolid
# 8                    University of Perugia
# 9                       Charles University
# 10                     University of Siena
# 11                     University of Pavia
# 12                    University of Vienna
# 13  Ruprecht Karl University of Heidelberg
# 14                 Jagiellonian University
# 15                      University of Pisa
# 16                     University of Turin
# 17                   University of Leipzig
# 18               University of St. Andrews
# 19                   University of Rostock
# 20                   University of Ferrara
# 21             Sapienza University of Rome
# 22                   University of Catania
# 23                 University of Barcelona
# 24                   University of Glasgow
# 25                University of Greifswald
# 26   Albert Ludwigs University of Freiburg
# 27                     University of Basel
# 28  Ludwig Maximilian University of Munich
# 29                University of Copenhagen
# 30   Eberhard Karls University of Tübingen
# 31                      Uppsala University
# 32                  University of Aberdeen
# 33        Complutense University of Madrid
# 34                  University of Valencia
#
#                                     H-Location                   G-Location  \
# 0          Kingdom of Italy, Holy Roman Empire               Bologna, Italy
# 2                           Kingdom of England    Cambridge, United Kingdom
# 3                              Kingdom of León             Salamanca, Spain
# 4                    Medieval commune of Padua                 Padua, Italy
# 5                            Kingdom of Sicily                Naples, Italy
# 6                          Kingdom of Portugal            Coimbra, Portugal
# 7                             Crown of Castile            Valladolid, Spain
# 8                                 Papal States               Perugia, Italy
# 9        Kingdom of Bohemia, Holy Roman Empire       Prague, Czech Republic
# 10                           Republic of Siena                 Siena, Italy
# 11             Domain of the House of Visconti                 Pavia, Italy
# 12                           Holy Roman Empire              Vienna, Austria
# 13                           Holy Roman Empire          Heidelberg, Germany
# 14                           Kingdom of Poland               Kraków, Poland
# 15                            Republic of Pisa                  Pisa, Italy
# 16                              Duchy of Savoy                 Turin, Italy
# 17                           Holy Roman Empire             Leipzig, Germany
# 18                         Kingdom of Scotland  St. Andrews, United Kingdom
# 19                           Holy Roman Empire             Rostock, Germany
# 20                               House of Este               Ferrara, Italy
# 21                                Papal States                  Rome, Italy
# 22                           Kingdom of Sicily               Catania, Italy
# 23                             Crown of Aragon             Barcelona, Spain
# 24                         Kingdom of Scotland      Glasgow, United Kingdom
# 25                           Holy Roman Empire          Greifswald, Germany
# 26                           Holy Roman Empire            Freiburg, Germany
# 27                           Holy Roman Empire           Basel, Switzerland
# 28                           Holy Roman Empire              Munich, Germany
# 29  Kingdom of Denmark within the Kalmar Union          Copenhagen, Denmark
# 30                           Holy Roman Empire            Tübingen, Germany
# 31   Kingdom of Sweden within the Kalmar Union              Uppsala, Sweden
# 32                         Kingdom of Scotland     Aberdeen, United Kingdom
# 33                            Crown of Castile                Madrid, Spain
# 34                             Crown of Aragon              Valencia, Spain
#
#                                                 Notes  year       G-City  \
# 0   Law schools existed in Bologna from the second...  1180      Bologna
# 2   Founded by scholars leaving Oxford after a dis...  1209    Cambridge
# 3   The oldest university in the Hispanic world. T...  1218    Salamanca
# 4   Founded by scholars and professors after leavi...  1222        Padua
# 5   Claims to be the oldest public university in t...  1224       Naples
# 6   Originally established in Lisbon but relocated...  1290      Coimbra
# 7   Founded in the late 13th century,[24] probably...  1293   Valladolid
# 8   The university traces its history back to 1276...  1308      Perugia
# 9   Faculties of theology, law and medicine closed...  1347       Prague
# 10  Claims to have been founded in 1240 by the Com...  1357        Siena
# 11  Transferred to Piacenza 1398–1412.[24] Closed ...  1361        Pavia
# 12                                                NaN  1365       Vienna
# 13                                                NaN  1385   Heidelberg
# 14  Founded by King Casimir the Great as a studium...  1397       Kraków
# 15  Established 1343 but closed around 1360; refou...  1400         Pisa
# 16                                                NaN  1404        Turin
# 17                                                NaN  1409      Leipzig
# 18  A school of higher studies was founded in 1410...  1410  St. Andrews
# 19  Continuous operation during the Reformation is...  1419      Rostock
# 20                                                NaN  1430      Ferrara
# 21  Founded in 1303 but closed at the end of the 1...  1431         Rome
# 22                                                NaN  1444      Catania
# 23  Founded by Alfonso V of Aragon on 3 September ...  1450    Barcelona
# 24                                                NaN  1451      Glasgow
# 25  Some professors from Rostock taught temporaril...  1456   Greifswald
# 26  A papal bull of 1455 authorised the Bishop of ...  1457     Freiburg
# 27                                                NaN  1459        Basel
# 28  Founded in Ingolstadt in 1472; with a papal bu...  1459       Munich
# 29                                                NaN  1475   Copenhagen
# 30                                                NaN  1476     Tübingen
# 31  Established in 1477 by the Catholic Archbishop...  1477      Uppsala
# 32  King's College was founded by a papal bull in ...  1495     Aberdeen
# 33  A studium generale was founded by Sancho IV of...  1499       Madrid
# 34                                                NaN  1500     Valencia
#
#           G-Country
# 0             Italy
# 2    United Kingdom
# 3             Spain
# 4             Italy
# 5             Italy
# 6          Portugal
# 7             Spain
# 8             Italy
# 9    Czech Republic
# 10            Italy
# 11            Italy
# 12          Austria
# 13          Germany
# 14           Poland
# 15            Italy
# 16            Italy
# 17          Germany
# 18   United Kingdom
# 19          Germany
# 20            Italy
# 21            Italy
# 22            Italy
# 23            Spain
# 24   United Kingdom
# 25          Germany
# 26          Germany
# 27      Switzerland
# 28          Germany
# 29          Denmark
# 30          Germany
# 31           Sweden
# 32   United Kingdom
# 33            Spain
# 34            Spain

# %%
udf.head(3)
# Out:
#                                    Year               University  \
# 0  1180–1190[10](teaching from c. 1088)    University of Bologna
# 1  1200–1214[15](teaching from c. 1096)     University of Oxford
# 2                         1209–1225[24]  University of Cambridge
#
#                             H-Location                 G-Location  \
# 0  Kingdom of Italy, Holy Roman Empire             Bologna, Italy
# 1                   Kingdom of England     Oxford, United Kingdom
# 2                   Kingdom of England  Cambridge, United Kingdom
#
#                                                Notes  year     G-City  \
# 0  Law schools existed in Bologna from the second...  1180    Bologna
# 1  Teaching existed in Oxford from the late 11th ...  1200     Oxford
# 2  Founded by scholars leaving Oxford after a dis...  1209  Cambridge
#
#          G-Country
# 0            Italy
# 1   United Kingdom
# 2   United Kingdom

# %%
udf.drop(columns=['G-Location', 'Year'])
# Out:
#                                 University  \
# 0                    University of Bologna
# 1                     University of Oxford
# 2                  University of Cambridge
# 3                  University of Salamanca
# 4                      University of Padua
# 5         University of Naples Federico II
# 6                    University of Coimbra
# 7                 University of Valladolid
# 8                    University of Perugia
# 9                       Charles University
# 10                     University of Siena
# 11                     University of Pavia
# 12                    University of Vienna
# 13  Ruprecht Karl University of Heidelberg
# 14                 Jagiellonian University
# 15                      University of Pisa
# 16                     University of Turin
# 17                   University of Leipzig
# 18               University of St. Andrews
# 19                   University of Rostock
# 20                   University of Ferrara
# 21             Sapienza University of Rome
# 22                   University of Catania
# 23                 University of Barcelona
# 24                   University of Glasgow
# 25                University of Greifswald
# 26   Albert Ludwigs University of Freiburg
# 27                     University of Basel
# 28  Ludwig Maximilian University of Munich
# 29                University of Copenhagen
# 30   Eberhard Karls University of Tübingen
# 31                      Uppsala University
# 32                  University of Aberdeen
# 33        Complutense University of Madrid
# 34                  University of Valencia
#
#                                     H-Location  \
# 0          Kingdom of Italy, Holy Roman Empire
# 1                           Kingdom of England
# 2                           Kingdom of England
# 3                              Kingdom of León
# 4                    Medieval commune of Padua
# 5                            Kingdom of Sicily
# 6                          Kingdom of Portugal
# 7                             Crown of Castile
# 8                                 Papal States
# 9        Kingdom of Bohemia, Holy Roman Empire
# 10                           Republic of Siena
# 11             Domain of the House of Visconti
# 12                           Holy Roman Empire
# 13                           Holy Roman Empire
# 14                           Kingdom of Poland
# 15                            Republic of Pisa
# 16                              Duchy of Savoy
# 17                           Holy Roman Empire
# 18                         Kingdom of Scotland
# 19                           Holy Roman Empire
# 20                               House of Este
# 21                                Papal States
# 22                           Kingdom of Sicily
# 23                             Crown of Aragon
# 24                         Kingdom of Scotland
# 25                           Holy Roman Empire
# 26                           Holy Roman Empire
# 27                           Holy Roman Empire
# 28                           Holy Roman Empire
# 29  Kingdom of Denmark within the Kalmar Union
# 30                           Holy Roman Empire
# 31   Kingdom of Sweden within the Kalmar Union
# 32                         Kingdom of Scotland
# 33                            Crown of Castile
# 34                             Crown of Aragon
#
#                                                 Notes  year       G-City  \
# 0   Law schools existed in Bologna from the second...  1180      Bologna
# 1   Teaching existed in Oxford from the late 11th ...  1200       Oxford
# 2   Founded by scholars leaving Oxford after a dis...  1209    Cambridge
# 3   The oldest university in the Hispanic world. T...  1218    Salamanca
# 4   Founded by scholars and professors after leavi...  1222        Padua
# 5   Claims to be the oldest public university in t...  1224       Naples
# 6   Originally established in Lisbon but relocated...  1290      Coimbra
# 7   Founded in the late 13th century,[24] probably...  1293   Valladolid
# 8   The university traces its history back to 1276...  1308      Perugia
# 9   Faculties of theology, law and medicine closed...  1347       Prague
# 10  Claims to have been founded in 1240 by the Com...  1357        Siena
# 11  Transferred to Piacenza 1398–1412.[24] Closed ...  1361        Pavia
# 12                                                NaN  1365       Vienna
# 13                                                NaN  1385   Heidelberg
# 14  Founded by King Casimir the Great as a studium...  1397       Kraków
# 15  Established 1343 but closed around 1360; refou...  1400         Pisa
# 16                                                NaN  1404        Turin
# 17                                                NaN  1409      Leipzig
# 18  A school of higher studies was founded in 1410...  1410  St. Andrews
# 19  Continuous operation during the Reformation is...  1419      Rostock
# 20                                                NaN  1430      Ferrara
# 21  Founded in 1303 but closed at the end of the 1...  1431         Rome
# 22                                                NaN  1444      Catania
# 23  Founded by Alfonso V of Aragon on 3 September ...  1450    Barcelona
# 24                                                NaN  1451      Glasgow
# 25  Some professors from Rostock taught temporaril...  1456   Greifswald
# 26  A papal bull of 1455 authorised the Bishop of ...  1457     Freiburg
# 27                                                NaN  1459        Basel
# 28  Founded in Ingolstadt in 1472; with a papal bu...  1459       Munich
# 29                                                NaN  1475   Copenhagen
# 30                                                NaN  1476     Tübingen
# 31  Established in 1477 by the Catholic Archbishop...  1477      Uppsala
# 32  King's College was founded by a papal bull in ...  1495     Aberdeen
# 33  A studium generale was founded by Sancho IV of...  1499       Madrid
# 34                                                NaN  1500     Valencia
#
#           G-Country
# 0             Italy
# 1    United Kingdom
# 2    United Kingdom
# 3             Spain
# 4             Italy
# 5             Italy
# 6          Portugal
# 7             Spain
# 8             Italy
# 9    Czech Republic
# 10            Italy
# 11            Italy
# 12          Austria
# 13          Germany
# 14           Poland
# 15            Italy
# 16            Italy
# 17          Germany
# 18   United Kingdom
# 19          Germany
# 20            Italy
# 21            Italy
# 22            Italy
# 23            Spain
# 24   United Kingdom
# 25          Germany
# 26          Germany
# 27      Switzerland
# 28          Germany
# 29          Denmark
# 30          Germany
# 31           Sweden
# 32   United Kingdom
# 33            Spain
# 34            Spain

# %% [markdown]
# Dataframe or series are not automatically "adjusted" except you use `inpace=True`

# %%
udf
# Out:
#                                            Year  \
# 0          1180–1190[10](teaching from c. 1088)
# 1          1200–1214[15](teaching from c. 1096)
# 2                                 1209–1225[24]
# 3                                 1218–1219[24]
# 4                                      1222[24]
# 5                                      1224[24]
# 6                                      1290[24]
# 7             1293 (Papal recognition 1346)[24]
# 8                                      1308[24]
# 9                                      1347[24]
# 10           1357[24](originally 1246–1252)[24]
# 11                                     1361[24]
# 12                                     1365[24]
# 13                                     1385[24]
# 14    1397[24](originally 1364-before 1370)[24]
# 15  c. 1400[24](originally 1343 to c. 1360)[24]
# 16                                     1404[24]
# 17                                     1409[24]
# 18                            1410[24]–1413[43]
# 19                                     1419[24]
# 20           1430[24](originally 1391–1394)[24]
# 21     1431[24](originally 1303 to c. 1400)[24]
# 22                                     1444[24]
# 23                                     1450[24]
# 24                                     1451[24]
# 25                                     1456[24]
# 26                                     1457[24]
# 27                                     1459[24]
# 28                            1459[24]–1472[60]
# 29                                     1475[24]
# 30                                     1476[24]
# 31                                     1477[24]
# 32                                     1495[24]
# 33                                     1499[24]
# 34                                     1500[24]
#
#                                 University  \
# 0                    University of Bologna
# 1                     University of Oxford
# 2                  University of Cambridge
# 3                  University of Salamanca
# 4                      University of Padua
# 5         University of Naples Federico II
# 6                    University of Coimbra
# 7                 University of Valladolid
# 8                    University of Perugia
# 9                       Charles University
# 10                     University of Siena
# 11                     University of Pavia
# 12                    University of Vienna
# 13  Ruprecht Karl University of Heidelberg
# 14                 Jagiellonian University
# 15                      University of Pisa
# 16                     University of Turin
# 17                   University of Leipzig
# 18               University of St. Andrews
# 19                   University of Rostock
# 20                   University of Ferrara
# 21             Sapienza University of Rome
# 22                   University of Catania
# 23                 University of Barcelona
# 24                   University of Glasgow
# 25                University of Greifswald
# 26   Albert Ludwigs University of Freiburg
# 27                     University of Basel
# 28  Ludwig Maximilian University of Munich
# 29                University of Copenhagen
# 30   Eberhard Karls University of Tübingen
# 31                      Uppsala University
# 32                  University of Aberdeen
# 33        Complutense University of Madrid
# 34                  University of Valencia
#
#                                     H-Location                   G-Location  \
# 0          Kingdom of Italy, Holy Roman Empire               Bologna, Italy
# 1                           Kingdom of England       Oxford, United Kingdom
# 2                           Kingdom of England    Cambridge, United Kingdom
# 3                              Kingdom of León             Salamanca, Spain
# 4                    Medieval commune of Padua                 Padua, Italy
# 5                            Kingdom of Sicily                Naples, Italy
# 6                          Kingdom of Portugal            Coimbra, Portugal
# 7                             Crown of Castile            Valladolid, Spain
# 8                                 Papal States               Perugia, Italy
# 9        Kingdom of Bohemia, Holy Roman Empire       Prague, Czech Republic
# 10                           Republic of Siena                 Siena, Italy
# 11             Domain of the House of Visconti                 Pavia, Italy
# 12                           Holy Roman Empire              Vienna, Austria
# 13                           Holy Roman Empire          Heidelberg, Germany
# 14                           Kingdom of Poland               Kraków, Poland
# 15                            Republic of Pisa                  Pisa, Italy
# 16                              Duchy of Savoy                 Turin, Italy
# 17                           Holy Roman Empire             Leipzig, Germany
# 18                         Kingdom of Scotland  St. Andrews, United Kingdom
# 19                           Holy Roman Empire             Rostock, Germany
# 20                               House of Este               Ferrara, Italy
# 21                                Papal States                  Rome, Italy
# 22                           Kingdom of Sicily               Catania, Italy
# 23                             Crown of Aragon             Barcelona, Spain
# 24                         Kingdom of Scotland      Glasgow, United Kingdom
# 25                           Holy Roman Empire          Greifswald, Germany
# 26                           Holy Roman Empire            Freiburg, Germany
# 27                           Holy Roman Empire           Basel, Switzerland
# 28                           Holy Roman Empire              Munich, Germany
# 29  Kingdom of Denmark within the Kalmar Union          Copenhagen, Denmark
# 30                           Holy Roman Empire            Tübingen, Germany
# 31   Kingdom of Sweden within the Kalmar Union              Uppsala, Sweden
# 32                         Kingdom of Scotland     Aberdeen, United Kingdom
# 33                            Crown of Castile                Madrid, Spain
# 34                             Crown of Aragon              Valencia, Spain
#
#                                                 Notes  year       G-City  \
# 0   Law schools existed in Bologna from the second...  1180      Bologna
# 1   Teaching existed in Oxford from the late 11th ...  1200       Oxford
# 2   Founded by scholars leaving Oxford after a dis...  1209    Cambridge
# 3   The oldest university in the Hispanic world. T...  1218    Salamanca
# 4   Founded by scholars and professors after leavi...  1222        Padua
# 5   Claims to be the oldest public university in t...  1224       Naples
# 6   Originally established in Lisbon but relocated...  1290      Coimbra
# 7   Founded in the late 13th century,[24] probably...  1293   Valladolid
# 8   The university traces its history back to 1276...  1308      Perugia
# 9   Faculties of theology, law and medicine closed...  1347       Prague
# 10  Claims to have been founded in 1240 by the Com...  1357        Siena
# 11  Transferred to Piacenza 1398–1412.[24] Closed ...  1361        Pavia
# 12                                                NaN  1365       Vienna
# 13                                                NaN  1385   Heidelberg
# 14  Founded by King Casimir the Great as a studium...  1397       Kraków
# 15  Established 1343 but closed around 1360; refou...  1400         Pisa
# 16                                                NaN  1404        Turin
# 17                                                NaN  1409      Leipzig
# 18  A school of higher studies was founded in 1410...  1410  St. Andrews
# 19  Continuous operation during the Reformation is...  1419      Rostock
# 20                                                NaN  1430      Ferrara
# 21  Founded in 1303 but closed at the end of the 1...  1431         Rome
# 22                                                NaN  1444      Catania
# 23  Founded by Alfonso V of Aragon on 3 September ...  1450    Barcelona
# 24                                                NaN  1451      Glasgow
# 25  Some professors from Rostock taught temporaril...  1456   Greifswald
# 26  A papal bull of 1455 authorised the Bishop of ...  1457     Freiburg
# 27                                                NaN  1459        Basel
# 28  Founded in Ingolstadt in 1472; with a papal bu...  1459       Munich
# 29                                                NaN  1475   Copenhagen
# 30                                                NaN  1476     Tübingen
# 31  Established in 1477 by the Catholic Archbishop...  1477      Uppsala
# 32  King's College was founded by a papal bull in ...  1495     Aberdeen
# 33  A studium generale was founded by Sancho IV of...  1499       Madrid
# 34                                                NaN  1500     Valencia
#
#           G-Country
# 0             Italy
# 1    United Kingdom
# 2    United Kingdom
# 3             Spain
# 4             Italy
# 5             Italy
# 6          Portugal
# 7             Spain
# 8             Italy
# 9    Czech Republic
# 10            Italy
# 11            Italy
# 12          Austria
# 13          Germany
# 14           Poland
# 15            Italy
# 16            Italy
# 17          Germany
# 18   United Kingdom
# 19          Germany
# 20            Italy
# 21            Italy
# 22            Italy
# 23            Spain
# 24   United Kingdom
# 25          Germany
# 26          Germany
# 27      Switzerland
# 28          Germany
# 29          Denmark
# 30          Germany
# 31           Sweden
# 32   United Kingdom
# 33            Spain
# 34            Spain

# %%
udf.drop(columns=['G-Location', 'Year'], inplace=True)

# %%
udf
# Out:
#                                 University  \
# 0                    University of Bologna
# 1                     University of Oxford
# 2                  University of Cambridge
# 3                  University of Salamanca
# 4                      University of Padua
# 5         University of Naples Federico II
# 6                    University of Coimbra
# 7                 University of Valladolid
# 8                    University of Perugia
# 9                       Charles University
# 10                     University of Siena
# 11                     University of Pavia
# 12                    University of Vienna
# 13  Ruprecht Karl University of Heidelberg
# 14                 Jagiellonian University
# 15                      University of Pisa
# 16                     University of Turin
# 17                   University of Leipzig
# 18               University of St. Andrews
# 19                   University of Rostock
# 20                   University of Ferrara
# 21             Sapienza University of Rome
# 22                   University of Catania
# 23                 University of Barcelona
# 24                   University of Glasgow
# 25                University of Greifswald
# 26   Albert Ludwigs University of Freiburg
# 27                     University of Basel
# 28  Ludwig Maximilian University of Munich
# 29                University of Copenhagen
# 30   Eberhard Karls University of Tübingen
# 31                      Uppsala University
# 32                  University of Aberdeen
# 33        Complutense University of Madrid
# 34                  University of Valencia
#
#                                     H-Location  \
# 0          Kingdom of Italy, Holy Roman Empire
# 1                           Kingdom of England
# 2                           Kingdom of England
# 3                              Kingdom of León
# 4                    Medieval commune of Padua
# 5                            Kingdom of Sicily
# 6                          Kingdom of Portugal
# 7                             Crown of Castile
# 8                                 Papal States
# 9        Kingdom of Bohemia, Holy Roman Empire
# 10                           Republic of Siena
# 11             Domain of the House of Visconti
# 12                           Holy Roman Empire
# 13                           Holy Roman Empire
# 14                           Kingdom of Poland
# 15                            Republic of Pisa
# 16                              Duchy of Savoy
# 17                           Holy Roman Empire
# 18                         Kingdom of Scotland
# 19                           Holy Roman Empire
# 20                               House of Este
# 21                                Papal States
# 22                           Kingdom of Sicily
# 23                             Crown of Aragon
# 24                         Kingdom of Scotland
# 25                           Holy Roman Empire
# 26                           Holy Roman Empire
# 27                           Holy Roman Empire
# 28                           Holy Roman Empire
# 29  Kingdom of Denmark within the Kalmar Union
# 30                           Holy Roman Empire
# 31   Kingdom of Sweden within the Kalmar Union
# 32                         Kingdom of Scotland
# 33                            Crown of Castile
# 34                             Crown of Aragon
#
#                                                 Notes  year       G-City  \
# 0   Law schools existed in Bologna from the second...  1180      Bologna
# 1   Teaching existed in Oxford from the late 11th ...  1200       Oxford
# 2   Founded by scholars leaving Oxford after a dis...  1209    Cambridge
# 3   The oldest university in the Hispanic world. T...  1218    Salamanca
# 4   Founded by scholars and professors after leavi...  1222        Padua
# 5   Claims to be the oldest public university in t...  1224       Naples
# 6   Originally established in Lisbon but relocated...  1290      Coimbra
# 7   Founded in the late 13th century,[24] probably...  1293   Valladolid
# 8   The university traces its history back to 1276...  1308      Perugia
# 9   Faculties of theology, law and medicine closed...  1347       Prague
# 10  Claims to have been founded in 1240 by the Com...  1357        Siena
# 11  Transferred to Piacenza 1398–1412.[24] Closed ...  1361        Pavia
# 12                                                NaN  1365       Vienna
# 13                                                NaN  1385   Heidelberg
# 14  Founded by King Casimir the Great as a studium...  1397       Kraków
# 15  Established 1343 but closed around 1360; refou...  1400         Pisa
# 16                                                NaN  1404        Turin
# 17                                                NaN  1409      Leipzig
# 18  A school of higher studies was founded in 1410...  1410  St. Andrews
# 19  Continuous operation during the Reformation is...  1419      Rostock
# 20                                                NaN  1430      Ferrara
# 21  Founded in 1303 but closed at the end of the 1...  1431         Rome
# 22                                                NaN  1444      Catania
# 23  Founded by Alfonso V of Aragon on 3 September ...  1450    Barcelona
# 24                                                NaN  1451      Glasgow
# 25  Some professors from Rostock taught temporaril...  1456   Greifswald
# 26  A papal bull of 1455 authorised the Bishop of ...  1457     Freiburg
# 27                                                NaN  1459        Basel
# 28  Founded in Ingolstadt in 1472; with a papal bu...  1459       Munich
# 29                                                NaN  1475   Copenhagen
# 30                                                NaN  1476     Tübingen
# 31  Established in 1477 by the Catholic Archbishop...  1477      Uppsala
# 32  King's College was founded by a papal bull in ...  1495     Aberdeen
# 33  A studium generale was founded by Sancho IV of...  1499       Madrid
# 34                                                NaN  1500     Valencia
#
#           G-Country
# 0             Italy
# 1    United Kingdom
# 2    United Kingdom
# 3             Spain
# 4             Italy
# 5             Italy
# 6          Portugal
# 7             Spain
# 8             Italy
# 9    Czech Republic
# 10            Italy
# 11            Italy
# 12          Austria
# 13          Germany
# 14           Poland
# 15            Italy
# 16            Italy
# 17          Germany
# 18   United Kingdom
# 19          Germany
# 20            Italy
# 21            Italy
# 22            Italy
# 23            Spain
# 24   United Kingdom
# 25          Germany
# 26          Germany
# 27      Switzerland
# 28          Germany
# 29          Denmark
# 30          Germany
# 31           Sweden
# 32   United Kingdom
# 33            Spain
# 34            Spain

# %% [markdown]
# # slicing and dicing

# %%
udf[:3] # df[:'r3'] works as well
# Out:
#                 University                           H-Location  \
# 0    University of Bologna  Kingdom of Italy, Holy Roman Empire
# 1     University of Oxford                   Kingdom of England
# 2  University of Cambridge                   Kingdom of England
#
#                                                Notes  year     G-City  \
# 0  Law schools existed in Bologna from the second...  1180    Bologna
# 1  Teaching existed in Oxford from the late 11th ...  1200     Oxford
# 2  Founded by scholars leaving Oxford after a dis...  1209  Cambridge
#
#          G-Country
# 0            Italy
# 1   United Kingdom
# 2   United Kingdom

# %%
# selecting one column!
udf['G-Country']
# Out:
# 0               Italy
# 1      United Kingdom
# 2      United Kingdom
# 3               Spain
# 4               Italy
# 5               Italy
# 6            Portugal
# 7               Spain
# 8               Italy
# 9      Czech Republic
# 10              Italy
# 11              Italy
# 12            Austria
# 13            Germany
# 14             Poland
# 15              Italy
# 16              Italy
# 17            Germany
# 18     United Kingdom
# 19            Germany
# 20              Italy
# 21              Italy
# 22              Italy
# 23              Spain
# 24     United Kingdom
# 25            Germany
# 26            Germany
# 27        Switzerland
# 28            Germany
# 29            Denmark
# 30            Germany
# 31             Sweden
# 32     United Kingdom
# 33              Spain
# 34              Spain
# Name: G-Country, dtype: object

# %%
udf.describe()
# Out:
#                    University         H-Location  \
# count                      35                 35
# unique                     35                 20
# top     University of Bologna  Holy Roman Empire
# freq                        1                  9
#
#                                                     Notes  year   G-City  \
# count                                                  24    35       35
# unique                                                 24    34       35
# top     Law schools existed in Bologna from the second...  1459  Bologna
# freq                                                    1     2        1
#
#        G-Country
# count         35
# unique        11
# top        Italy
# freq          11

# %%
# selecting one row
udf.loc[1]
# Out:
# University                                 University of Oxford
# H-Location                                   Kingdom of England
# Notes         Teaching existed in Oxford from the late 11th ...
# year                                                       1200
# G-City                                                   Oxford
# G-Country                                        United Kingdom
# Name: 1, dtype: object

# %%
udf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   University  35 non-null     object
#  1   H-Location  35 non-null     object
#  2   Notes       24 non-null     object
#  3   year        35 non-null     object
#  4   G-City      35 non-null     object
#  5   G-Country   35 non-null     object
# dtypes: object(6)
# memory usage: 1.8+ KB

# %%
# mask also work on df!
mask = udf['year'] < 1400
mask.head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/23/815dys2s2r5dyf7cqkfnn4t00000r9/T/ipykernel_7138/4248561953.py in <module>
#       1 # mask also work on df!
# ----> 2 mask = udf['year'] < 1400
#       3 mask.head(10)
#
# ~/dev/_teaching/advanced_python_2021-22_HD_pre/.venv/lib/python3.7/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~/dev/_teaching/advanced_python_2021-22_HD_pre/.venv/lib/python3.7/site-packages/pandas/core/arraylike.py in __lt__(self, other)
#      38     @unpack_zerodim_and_defer("__lt__")
#      39     def __lt__(self, other):
# ---> 40         return self._cmp_method(other, operator.lt)
#      41
#      42     @unpack_zerodim_and_defer("__le__")
#
# ~/dev/_teaching/advanced_python_2021-22_HD_pre/.venv/lib/python3.7/site-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    5500
#    5501         with np.errstate(all="ignore"):
# -> 5502             res_values = ops.comparison_op(lvalues, rvalues, op)
#    5503
#    5504         return self._construct_result(res_values, name=res_name)
#
# ~/dev/_teaching/advanced_python_2021-22_HD_pre/.venv/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     282
#     283     elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 284         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     285
#     286     else:
#
# ~/dev/_teaching/advanced_python_2021-22_HD_pre/.venv/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      71         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      72     else:
# ---> 73         result = libops.scalar_compare(x.ravel(), y, op)
#      74     return result.reshape(x.shape)
#      75
#
# ~/dev/_teaching/advanced_python_2021-22_HD_pre/.venv/lib/python3.7/site-packages/pandas/_libs/ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
# casting columns into data types
udf.year = udf.year.astype(int)

# %%
_udf = udf.convert_dtypes()

# %%
_udf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   University  35 non-null     string
#  1   H-Location  35 non-null     string
#  2   Notes       24 non-null     string
#  3   year        35 non-null     Int64
#  4   G-City      35 non-null     string
#  5   G-Country   35 non-null     string
# dtypes: Int64(1), string(5)
# memory usage: 1.8 KB

# %%
# mask also work on df!
mask = udf.year < 1400
mask.head(10)
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# Name: year, dtype: bool

# %%
udf[mask]
# Out:
#                                 University  \
# 0                    University of Bologna
# 1                     University of Oxford
# 2                  University of Cambridge
# 3                  University of Salamanca
# 4                      University of Padua
# 5         University of Naples Federico II
# 6                    University of Coimbra
# 7                 University of Valladolid
# 8                    University of Perugia
# 9                       Charles University
# 10                     University of Siena
# 11                     University of Pavia
# 12                    University of Vienna
# 13  Ruprecht Karl University of Heidelberg
# 14                 Jagiellonian University
#
#                                H-Location  \
# 0     Kingdom of Italy, Holy Roman Empire
# 1                      Kingdom of England
# 2                      Kingdom of England
# 3                         Kingdom of León
# 4               Medieval commune of Padua
# 5                       Kingdom of Sicily
# 6                     Kingdom of Portugal
# 7                        Crown of Castile
# 8                            Papal States
# 9   Kingdom of Bohemia, Holy Roman Empire
# 10                      Republic of Siena
# 11        Domain of the House of Visconti
# 12                      Holy Roman Empire
# 13                      Holy Roman Empire
# 14                      Kingdom of Poland
#
#                                                 Notes  year      G-City  \
# 0   Law schools existed in Bologna from the second...  1180     Bologna
# 1   Teaching existed in Oxford from the late 11th ...  1200      Oxford
# 2   Founded by scholars leaving Oxford after a dis...  1209   Cambridge
# 3   The oldest university in the Hispanic world. T...  1218   Salamanca
# 4   Founded by scholars and professors after leavi...  1222       Padua
# 5   Claims to be the oldest public university in t...  1224      Naples
# 6   Originally established in Lisbon but relocated...  1290     Coimbra
# 7   Founded in the late 13th century,[24] probably...  1293  Valladolid
# 8   The university traces its history back to 1276...  1308     Perugia
# 9   Faculties of theology, law and medicine closed...  1347      Prague
# 10  Claims to have been founded in 1240 by the Com...  1357       Siena
# 11  Transferred to Piacenza 1398–1412.[24] Closed ...  1361       Pavia
# 12                                                NaN  1365      Vienna
# 13                                                NaN  1385  Heidelberg
# 14  Founded by King Casimir the Great as a studium...  1397      Kraków
#
#           G-Country
# 0             Italy
# 1    United Kingdom
# 2    United Kingdom
# 3             Spain
# 4             Italy
# 5             Italy
# 6          Portugal
# 7             Spain
# 8             Italy
# 9    Czech Republic
# 10            Italy
# 11            Italy
# 12          Austria
# 13          Germany
# 14           Poland

# %%
udf[udf['year'] < 1300] # reduces the data frame, again note! that is just a view, not a copy!
# Out:
#                          University                           H-Location  \
# 0             University of Bologna  Kingdom of Italy, Holy Roman Empire
# 1              University of Oxford                   Kingdom of England
# 2           University of Cambridge                   Kingdom of England
# 3           University of Salamanca                      Kingdom of León
# 4               University of Padua            Medieval commune of Padua
# 5  University of Naples Federico II                    Kingdom of Sicily
# 6             University of Coimbra                  Kingdom of Portugal
# 7          University of Valladolid                     Crown of Castile
#
#                                                Notes  year      G-City  \
# 0  Law schools existed in Bologna from the second...  1180     Bologna
# 1  Teaching existed in Oxford from the late 11th ...  1200      Oxford
# 2  Founded by scholars leaving Oxford after a dis...  1209   Cambridge
# 3  The oldest university in the Hispanic world. T...  1218   Salamanca
# 4  Founded by scholars and professors after leavi...  1222       Padua
# 5  Claims to be the oldest public university in t...  1224      Naples
# 6  Originally established in Lisbon but relocated...  1290     Coimbra
# 7  Founded in the late 13th century,[24] probably...  1293  Valladolid
#
#          G-Country
# 0            Italy
# 1   United Kingdom
# 2   United Kingdom
# 3            Spain
# 4            Italy
# 5            Italy
# 6         Portugal
# 7            Spain

# %%
udf[udf['year'] < 1300].loc[1]
# Out:
# University                                 University of Oxford
# H-Location                                   Kingdom of England
# Notes         Teaching existed in Oxford from the late 11th ...
# year                                                       1200
# G-City                                                   Oxford
# G-Country                                        United Kingdom
# Name: 1, dtype: object

# %%
udf[udf['year'] > 1300].loc[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/dev/_teaching/advanced_python_2021-22_HD_pre/.venv/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/dev/_teaching/advanced_python_2021-22_HD_pre/.venv/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/dev/_teaching/advanced_python_2021-22_HD_pre/.venv/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/23/815dys2s2r5dyf7cqkfnn4t00000r9/T/ipykernel_7138/2662739196.py in <module>
# ----> 1 udf[udf['year'] > 1300].loc[1]
#
# ~/dev/_teaching/advanced_python_2021-22_HD_pre/.venv/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~/dev/_teaching/advanced_python_2021-22_HD_pre/.venv/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/dev/_teaching/advanced_python_2021-22_HD_pre/.venv/lib/python3.7/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1111     def _get_label(self, label, axis: int):
#    1112         # GH#5667 this will fail if the label is not present in the axis.
# -> 1113         return self.obj.xs(label, axis=axis)
#    1114
#    1115     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# ~/dev/_teaching/advanced_python_2021-22_HD_pre/.venv/lib/python3.7/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3774                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3775         else:
# -> 3776             loc = index.get_loc(key)
#    3777
#    3778             if isinstance(loc, np.ndarray):
#
# ~/dev/_teaching/advanced_python_2021-22_HD_pre/.venv/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 1

# %%
udf[udf['year'] > 1300].head(3)
# Out:
#                University                             H-Location  \
# 8   University of Perugia                           Papal States
# 9      Charles University  Kingdom of Bohemia, Holy Roman Empire
# 10    University of Siena                      Republic of Siena
#
#                                                 Notes  year   G-City  \
# 8   The university traces its history back to 1276...  1308  Perugia
# 9   Faculties of theology, law and medicine closed...  1347   Prague
# 10  Claims to have been founded in 1240 by the Com...  1357    Siena
#
#           G-Country
# 8             Italy
# 9    Czech Republic
# 10            Italy

# %%
# How would I know which index is the first one in my masked selection ?
# Answer: you don't need to if you use iloc! :)
udf[udf['year'] > 1300].iloc[0]
# Out:
# University                                University of Perugia
# H-Location                                         Papal States
# Notes         The university traces its history back to 1276...
# year                                                       1308
# G-City                                                  Perugia
# G-Country                                                 Italy
# Name: 8, dtype: object

# %% [markdown]
# ## more natural query - or isn't it?

# %%
udf.query("year > 1300").head(5)
# Out:
#                University                             H-Location  \
# 8   University of Perugia                           Papal States
# 9      Charles University  Kingdom of Bohemia, Holy Roman Empire
# 10    University of Siena                      Republic of Siena
# 11    University of Pavia        Domain of the House of Visconti
# 12   University of Vienna                      Holy Roman Empire
#
#                                                 Notes  year   G-City  \
# 8   The university traces its history back to 1276...  1308  Perugia
# 9   Faculties of theology, law and medicine closed...  1347   Prague
# 10  Claims to have been founded in 1240 by the Com...  1357    Siena
# 11  Transferred to Piacenza 1398–1412.[24] Closed ...  1361    Pavia
# 12                                                NaN  1365   Vienna
#
#           G-Country
# 8             Italy
# 9    Czech Republic
# 10            Italy
# 11            Italy
# 12          Austria

# %%
udf.query("1349 > year > 1320")
# Out:
#            University                             H-Location  \
# 9  Charles University  Kingdom of Bohemia, Holy Roman Empire
#
#                                                Notes  year  G-City  \
# 9  Faculties of theology, law and medicine closed...  1347  Prague
#
#          G-Country
# 9   Czech Republic

# %%
# Using local variables in queries
upper_limit = 1400
udf.query("@upper_limit > year > 1320")
# Out:
#                                 University  \
# 9                       Charles University
# 10                     University of Siena
# 11                     University of Pavia
# 12                    University of Vienna
# 13  Ruprecht Karl University of Heidelberg
# 14                 Jagiellonian University
#
#                                H-Location  \
# 9   Kingdom of Bohemia, Holy Roman Empire
# 10                      Republic of Siena
# 11        Domain of the House of Visconti
# 12                      Holy Roman Empire
# 13                      Holy Roman Empire
# 14                      Kingdom of Poland
#
#                                                 Notes  year      G-City  \
# 9   Faculties of theology, law and medicine closed...  1347      Prague
# 10  Claims to have been founded in 1240 by the Com...  1357       Siena
# 11  Transferred to Piacenza 1398–1412.[24] Closed ...  1361       Pavia
# 12                                                NaN  1365      Vienna
# 13                                                NaN  1385  Heidelberg
# 14  Founded by King Casimir the Great as a studium...  1397      Kraków
#
#           G-Country
# 9    Czech Republic
# 10            Italy
# 11            Italy
# 12          Austria
# 13          Germany
# 14           Poland

# %% [markdown]
# ## Find the maximum for a given series or dataframe

# %%
udf['year'].idxmax()
# Out:
# 34

# %% [markdown]
# ## Unique values and their count

# %%
udf['G-Country'].unique()
# Out:
# array([' Italy', ' United Kingdom', ' Spain', ' Portugal',
#        ' Czech Republic', ' Austria', ' Germany', ' Poland',
#        ' Switzerland', ' Denmark', ' Sweden'], dtype=object)

# %%
udf['G-Country'].nunique()
# Out:
# 11

# %%
udf['G-Country'].value_counts()
# Out:
#  Italy             11
#  Germany            7
#  United Kingdom     5
#  Spain              5
#  Portugal           1
#  Czech Republic     1
#  Austria            1
#  Poland             1
#  Switzerland        1
#  Denmark            1
#  Sweden             1
# Name: G-Country, dtype: int64

# %%
_udf = udf.set_index('University')

# %%
# Grab some ramdom rows
_udf.sample(5)
# Out:
#                                                                         H-Location  \
# University
# Ruprecht Karl University of Heidelberg                           Holy Roman Empire
# University of Copenhagen                Kingdom of Denmark within the Kalmar Union
# University of Ferrara                                                House of Este
# University of Pisa                                                Republic of Pisa
# University of Valencia                                             Crown of Aragon
#
#                                                                                     Notes  \
# University
# Ruprecht Karl University of Heidelberg                                                NaN
# University of Copenhagen                                                              NaN
# University of Ferrara                                                                 NaN
# University of Pisa                      Established 1343 but closed around 1360; refou...
# University of Valencia                                                                NaN
#
#                                         year      G-City G-Country
# University
# Ruprecht Karl University of Heidelberg  1385  Heidelberg   Germany
# University of Copenhagen                1475  Copenhagen   Denmark
# University of Ferrara                   1430     Ferrara     Italy
# University of Pisa                      1400        Pisa     Italy
# University of Valencia                  1500    Valencia     Spain

# %%
_udf.loc['Ruprecht Karl University of Heidelberg', ['Notes', 'year']]
# Out:
# Notes     NaN
# year     1385
# Name: Ruprecht Karl University of Heidelberg, dtype: object

# %%
_udf.loc['Ruprecht Karl University of Heidelberg', :]
# Out:
# H-Location    Holy Roman Empire
# Notes                       NaN
# year                       1385
# G-City               Heidelberg
# G-Country               Germany
# Name: Ruprecht Karl University of Heidelberg, dtype: object

# %% [markdown]
# ## Done with Basics!
# Take a look at the cheat sheet for a summary
# https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf

# %% [markdown]
# # Hierarchical indexing

# %%
s = pd.Series(
        np.random.randn(5), 
        index = [
            ['p1','p1','p2','p2','p3'],
            ['a','b','a','d','a']
        ]
)
s
# Out:
# p1  a   -0.011814
#     b    1.490779
# p2  a    1.050917
#     d    0.731094
# p3  a    1.273402
# dtype: float64

# %%
s.index
# Out:
# MultiIndex([('p1', 'a'),
#             ('p1', 'b'),
#             ('p2', 'a'),
#             ('p2', 'd'),
#             ('p3', 'a')],
#            )

# %%
s.index.names = ['probability', 'type']

# %%
s
# Out:
# probability  type
# p1           a      -0.011814
#              b       1.490779
# p2           a       1.050917
#              d       0.731094
# p3           a       1.273402
# dtype: float64

# %%
s['p1']
# Out:
# type
# a   -0.011814
# b    1.490779
# dtype: float64

# %%
s[:, 'a'] # lower level
# Out:
# probability
# p1   -0.011814
# p2    1.050917
# p3    1.273402
# dtype: float64

# %%
s2 = s.unstack()
print(type(s2))
s2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# type                a         b         d
# probability
# p1          -0.011814  1.490779       NaN
# p2           1.050917       NaN  0.731094
# p3           1.273402       NaN       NaN

# %%
s3 = s2.stack()
print(type(s3))
s3
# Out:
# <class 'pandas.core.series.Series'>
# probability  type
# p1           a      -0.011814
#              b       1.490779
# p2           a       1.050917
#              d       0.731094
# p3           a       1.273402
# dtype: float64

# %% [markdown]
# ## Multindex with Dataframes

# %%
df = pd.DataFrame(
    [
        c, 
        c * 20, 
        d,
        np.exp(d),
        pd.Series(np.random.randn(4), index=['r2', 'r3', 'r4', 'r5'])
    ],
    index = [
        ['p1','p1','p2','p2','p3'],
        ['a','b','a','d','a']
    ]
)
df.index.names = ['probability', 'type']
df
# Out:
#                             r1            r2            r3            r4  \
# probability type
# p1          a        12.000000  1.300000e+01  1.400000e+01  1.210000e+02
#             b       240.000000  2.600000e+02  2.800000e+02  2.420000e+03
# p2          a        10.000000  2.000000e+01  3.000000e+01  4.000000e+01
#             d     22026.465795  4.851652e+08  1.068647e+13  2.353853e+17
# p3          a              NaN -2.739108e-01 -9.348187e-01 -3.950298e-01
#
#                         r5
# probability type
# p1          a          NaN
#             b          NaN
# p2          a          NaN
#             d          NaN
# p3          a    -0.041126

# %%
df = df.fillna(0)
df
# Out:
#                             r1            r2            r3            r4  \
# probability type
# p1          a        12.000000  1.300000e+01  1.400000e+01  1.210000e+02
#             b       240.000000  2.600000e+02  2.800000e+02  2.420000e+03
# p2          a        10.000000  2.000000e+01  3.000000e+01  4.000000e+01
#             d     22026.465795  4.851652e+08  1.068647e+13  2.353853e+17
# p3          a         0.000000 -2.739108e-01 -9.348187e-01 -3.950298e-01
#
#                         r5
# probability type
# p1          a     0.000000
#             b     0.000000
# p2          a     0.000000
#             d     0.000000
# p3          a    -0.041126

# %% [markdown]
# **Note**:
# You can create multi indeces from a regular dataframe!

# %%
df2 = df.reset_index()

# %%
df2
# Out:
#   probability type            r1            r2            r3            r4  \
# 0          p1    a     12.000000  1.300000e+01  1.400000e+01  1.210000e+02
# 1          p1    b    240.000000  2.600000e+02  2.800000e+02  2.420000e+03
# 2          p2    a     10.000000  2.000000e+01  3.000000e+01  4.000000e+01
# 3          p2    d  22026.465795  4.851652e+08  1.068647e+13  2.353853e+17
# 4          p3    a      0.000000 -2.739108e-01 -9.348187e-01 -3.950298e-01
#
#          r5
# 0  0.000000
# 1  0.000000
# 2  0.000000
# 3  0.000000
# 4 -0.041126

# %%
df2.set_index(['probability', 'type'])
# Out:
#                             r1            r2            r3            r4  \
# probability type
# p1          a        12.000000  1.300000e+01  1.400000e+01  1.210000e+02
#             b       240.000000  2.600000e+02  2.800000e+02  2.420000e+03
# p2          a        10.000000  2.000000e+01  3.000000e+01  4.000000e+01
#             d     22026.465795  4.851652e+08  1.068647e+13  2.353853e+17
# p3          a         0.000000 -2.739108e-01 -9.348187e-01 -3.950298e-01
#
#                         r5
# probability type
# p1          a     0.000000
#             b     0.000000
# p2          a     0.000000
#             d     0.000000
# p3          a    -0.041126

# %%
df2 = df.swaplevel('probability', 'type')
df2
# Out:
#                             r1            r2            r3            r4  \
# type probability
# a    p1              12.000000  1.300000e+01  1.400000e+01  1.210000e+02
# b    p1             240.000000  2.600000e+02  2.800000e+02  2.420000e+03
# a    p2              10.000000  2.000000e+01  3.000000e+01  4.000000e+01
# d    p2           22026.465795  4.851652e+08  1.068647e+13  2.353853e+17
# a    p3               0.000000 -2.739108e-01 -9.348187e-01 -3.950298e-01
#
#                         r5
# type probability
# a    p1           0.000000
# b    p1           0.000000
# a    p2           0.000000
# d    p2           0.000000
# a    p3          -0.041126

# %%
df2.sort_index(axis=0, level=0, inplace=True)

# %%
df2
# Out:
#                             r1            r2            r3            r4  \
# type probability
# a    p1              12.000000  1.300000e+01  1.400000e+01  1.210000e+02
#      p2              10.000000  2.000000e+01  3.000000e+01  4.000000e+01
#      p3               0.000000 -2.739108e-01 -9.348187e-01 -3.950298e-01
# b    p1             240.000000  2.600000e+02  2.800000e+02  2.420000e+03
# d    p2           22026.465795  4.851652e+08  1.068647e+13  2.353853e+17
#
#                         r5
# type probability
# a    p1           0.000000
#      p2           0.000000
#      p3          -0.041126
# b    p1           0.000000
# d    p2           0.000000

# %% [markdown]
# ## Natural slicing using `pandas.IndexSlice`  objects

# %%
idx = pd.IndexSlice
df2.loc[
    idx[:, ["p1", "p2"]], 
    :
]
# Out:
#                             r1            r2            r3            r4   r5
# type probability
# a    p1              12.000000  1.300000e+01  1.400000e+01  1.210000e+02  0.0
#      p2              10.000000  2.000000e+01  3.000000e+01  4.000000e+01  0.0
# b    p1             240.000000  2.600000e+02  2.800000e+02  2.420000e+03  0.0
# d    p2           22026.465795  4.851652e+08  1.068647e+13  2.353853e+17  0.0

# %% [markdown]
# ## long and wide formats

# %% [markdown]
# Long formats - easy to read and to handle for computers - each variable has its own column
#
# Wide formats - easy to read for humans - each observation has its own row

# %%
df3 = df2.reset_index()
df3.sort_values(["probability", "type"], inplace=True)
df3
# Out:
#   type probability            r1            r2            r3            r4  \
# 0    a          p1     12.000000  1.300000e+01  1.400000e+01  1.210000e+02
# 3    b          p1    240.000000  2.600000e+02  2.800000e+02  2.420000e+03
# 1    a          p2     10.000000  2.000000e+01  3.000000e+01  4.000000e+01
# 4    d          p2  22026.465795  4.851652e+08  1.068647e+13  2.353853e+17
# 2    a          p3      0.000000 -2.739108e-01 -9.348187e-01 -3.950298e-01
#
#          r5
# 0  0.000000
# 3  0.000000
# 1  0.000000
# 4  0.000000
# 2 -0.041126

# %%
df4 = df3.melt(
    id_vars=['type','probability'],
    var_name='r_stage',
    value_name='score'
)
print(df4.shape)
df4.sort_values(["type", "probability"], inplace=True)
df4.head(7)
# Out:
# (25, 4)
#    type probability r_stage  score
# 0     a          p1      r1   12.0
# 5     a          p1      r2   13.0
# 10    a          p1      r3   14.0
# 15    a          p1      r4  121.0
# 20    a          p1      r5    0.0
# 2     a          p2      r1   10.0
# 7     a          p2      r2   20.0

# %% [markdown]
# Think of selecting data, for example for plotting that should have the following criteria
# * probability == p1
# * r_stage in [r2, r3]

# %% [markdown]
# much easier in long format

# %%
# going back to the more human friendlier version ! :)

df5 = df4.pivot_table(index=['type', 'probability'], columns='r_stage', values="score")
df5
# Out:
# r_stage                     r1            r2            r3            r4  \
# type probability
# a    p1              12.000000  1.300000e+01  1.400000e+01  1.210000e+02
#      p2              10.000000  2.000000e+01  3.000000e+01  4.000000e+01
#      p3               0.000000 -2.739108e-01 -9.348187e-01 -3.950298e-01
# b    p1             240.000000  2.600000e+02  2.800000e+02  2.420000e+03
# d    p2           22026.465795  4.851652e+08  1.068647e+13  2.353853e+17
#
# r_stage                 r5
# type probability
# a    p1           0.000000
#      p2           0.000000
#      p3          -0.041126
# b    p1           0.000000
# d    p2           0.000000
